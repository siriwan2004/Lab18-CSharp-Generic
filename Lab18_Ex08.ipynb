// %% [markdown]
// # Lab 18 Exercise 8

// %% [markdown]
// ## Generic queue

// %% [markdown]
// 1.สร้าง console application project
//
// ```cmd
// dotnet new console --name Lab18_Ex08
// ```

// %% [markdown]
// 2.เปลี่ยน code ให้เป็นดังต่อไปนี้
//
// ```csharp
// using System;
// using System.Collections.Generic;
//
// Queue<int> numbers = new Queue<int>();
//
// System.Console.WriteLine("Add 3 elements (5, 10, 15)");
// numbers.Enqueue(5);
// numbers.Enqueue(10);
// numbers.Enqueue(15);
//
// System.Console.WriteLine("Items in queue:");
// foreach (var item in numbers)
// {
//     System.Console.WriteLine(item);
// }
//
// System.Console.Write("Remove first item in queue : ");
// var removeItem = numbers.Dequeue();
// System.Console.WriteLine(removeItem);
//
// System.Console.WriteLine("Remaining items in queue:");
// foreach (var item in numbers)
// {
//     System.Console.WriteLine(item);
// }
// ```

// %% [markdown]
// 3.Build project โดยการใช้คำสั่ง
//
// ```cmd
// dotnet build  Lab18_Ex08
// ```
//
// ถ้ามีที่ผิดพลาดในโปรแกรม ให้แก้ไขให้ถูกต้อง

// %% [markdown]
// 4.บันทึกผลที่ได้จากการรันคำสั่งในข้อ 3

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// 5.Run project โดยการใช้คำสั่ง
//
// ```cmd
// dotnet run --project Lab18_Ex08
// ```

// %% [markdown]
// 6.บันทึกผลที่ได้จากการรันคำสั่งในข้อ 5

// %% [markdown]
// ![image.png](attachment:image.png)

// %% [markdown]
// 7.อธิบายสิ่งที่พบในการทดลอง

// %% [markdown]
// ใช้ Queue<T> จาก System.Collections.Generic ซึ่งเป็นโครงสร้างข้อมูลแบบ คิว (Queue) ถ้าคิวว่างแล้วใช้ Dequeue() จะเกิด InvalidOperationException
//
// ควรตรวจสอบด้วย numbers.Count > 0 ก่อนถ้าต้องการแค่ดูตัวแรกในคิวโดยไม่ลบออก ใช้ Peek()
